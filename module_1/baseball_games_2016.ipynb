# %% [markdown]
# ## Baseball Games - Season 2016

# %% [markdown]
# ### with NumPy and Pandas

# %% [markdown]
# *Dataset columns:*
#
# * attendance - number of spectators at the game
# * away_team - guest team
# * away_team_errors
# * away_team_hits
# * away_team_runs
# * date
# * field_type
# * game_type
# * home_team
# * home_team_errors
# * home_team_hits
# * home_team_runs
# * start_time
# * venue - the name of the stadium, field, or arena
# * day_of_week
# * temperature - in Fahrenheits
# * wind_speed
# * wind_direction
# * sky
# * total_runs
# * game_hours_dec - game duration indicated in hours
# * season
# * home_team_win - (1 - Win)
# * home_team_loss - (0 - Loss)
# * home_team_outcome (Win, Loss)

# %%
import numpy as np
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('baseball_games.csv')
data.head(3)
# Out:
#    Unnamed: 0  attendance              away_team  away_team_errors  \
# 0           0     40030.0          New York Mets                 1
# 1           1     21621.0  Philadelphia Phillies                 0
# 2           2     12622.0        Minnesota Twins                 0
#
#    away_team_hits  away_team_runs        date field_type   game_type  \
# 0               7               3  2016-04-03   on grass  Night Game
# 1               5               2  2016-04-06   on grass  Night Game
# 2               5               2  2016-04-06   on grass  Night Game
#
#             home_team  home_team_errors  home_team_hits  home_team_runs  \
# 0  Kansas City Royals                 0               9               4
# 1     Cincinnati Reds                 0               8               3
# 2   Baltimore Orioles                 0               9               4
#
#         start_time                        venue day_of_week  temperature  \
# 0  7:38 p.m. Local             Kauffman Stadium      Sunday         74.0
# 1  7:11 p.m. Local     Great American Ball Park   Wednesday         55.0
# 2  7:07 p.m. Local  Oriole Park at Camden Yards   Wednesday         48.0
#
#    wind_speed       wind_direction       sky  total_runs  game_hours_dec  \
# 0        14.0   from Right to Left     Sunny           7        3.216667
# 1        24.0   from Right to Left  Overcast           5        2.383333
# 2         7.0     out to Leftfield   Unknown           6        3.183333
#
#            season  home_team_win  home_team_loss home_team_outcome
# 0  regular season              1               0               Win
# 1  regular season              1               0               Win
# 2  regular season              1               0               Win

# %%
df = data.drop(columns=['Unnamed: 0', 'away_team_errors', 'field_type',
                        'venue', 'wind_direction', 'sky']).copy()
df.sample(4)
# Out:
#       attendance              away_team  away_team_hits  away_team_runs  \
# 1489     18024.0         Boston Red Sox              12               7
# 39       24333.0      Chicago White Sox              11               7
# 875      13576.0         Boston Red Sox               9               6
# 1035     42859.0  Philadelphia Phillies               9               3
#
#             date   game_type            home_team  home_team_errors  \
# 1489  2016-06-27  Night Game       Tampa Bay Rays                 0
# 39    2016-04-25  Night Game    Toronto Blue Jays                 0
# 875   2016-08-22  Night Game       Tampa Bay Rays                 1
# 1035  2016-08-09  Night Game  Los Angeles Dodgers                 0
#
#       home_team_hits  home_team_runs       start_time day_of_week  \
# 1489              18              13  7:10 p.m. Local      Monday
# 39                14               5  7:08 p.m. Local      Monday
# 875                5               2  7:10 p.m. Local      Monday
# 1035              13               9  7:09 p.m. Local     Tuesday
#
#       temperature  wind_speed  total_runs  game_hours_dec          season  \
# 1489         72.0         0.0          20        3.483333  regular season
# 39           68.0         0.0          12        3.400000  regular season
# 875          72.0         0.0           8        3.216667  regular season
# 1035         75.0         8.0          12        3.283333  regular season
#
#       home_team_win  home_team_loss home_team_outcome
# 1489              1               0               Win
# 39                0               1              Loss
# 875               0               1              Loss
# 1035              1               0               Win

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2463 entries, 0 to 2462
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   attendance         2460 non-null   float64
#  1   away_team          2463 non-null   object
#  2   away_team_hits     2463 non-null   int64
#  3   away_team_runs     2463 non-null   int64
#  4   date               2463 non-null   object
#  5   game_type          2463 non-null   object
#  6   home_team          2463 non-null   object
#  7   home_team_errors   2463 non-null   int64
#  8   home_team_hits     2463 non-null   int64
#  9   home_team_runs     2463 non-null   int64
#  10  start_time         2463 non-null   object
#  11  day_of_week        2463 non-null   object
#  12  temperature        2463 non-null   float64
#  13  wind_speed         2463 non-null   float64
#  14  total_runs         2463 non-null   int64
#  15  game_hours_dec     2463 non-null   float64
#  16  season             2463 non-null   object
#  17  home_team_win      2463 non-null   int64
#  18  home_team_loss     2463 non-null   int64
#  19  home_team_outcome  2463 non-null   object
# dtypes: float64(4), int64(8), object(8)
# memory usage: 385.0+ KB

# %%
print(f"Types of season: {list(df.season.unique())}")
# Out:
# Types of season: ['regular season', 'post season']

# %%
# Remove the post season since the regular one is the only targeted one.
df.drop(df[df['season'] == 'post season'].index, inplace=True)
print(f"Number of games in the regular season: {int(df.season.value_counts())}")
# Out:
# Number of games in the regular season: 2428

# %%
df.loc[pd.isnull(df['attendance'])]
# Out:
#       attendance            away_team  away_team_hits  away_team_runs  \
# 220          NaN  St. Louis Cardinals               8               3
# 1724         NaN        New York Mets               5               1
# 1912         NaN    Cleveland Indians               7               6
#
#             date game_type           home_team  home_team_errors  \
# 220   2016-07-26  Day Game       New York Mets                 1
# 1724  2016-06-07  Day Game  Pittsburgh Pirates                 0
# 1912  2016-05-23  Day Game   Chicago White Sox                 0
#
#       home_team_hits  home_team_runs       start_time day_of_week  \
# 220                7               2  4:11 p.m. Local     Tuesday
# 1724              10               3  4:08 p.m. Local     Tuesday
# 1912              10               7  4:10 p.m. Local      Monday
#
#       temperature  wind_speed  total_runs  game_hours_dec          season  \
# 220          90.0        11.0           5        3.300000  regular season
# 1724         65.0        17.0           4        2.666667  regular season
# 1912         82.0        11.0          13        3.166667  regular season
#
#       home_team_win  home_team_loss home_team_outcome
# 220               0               1              Loss
# 1724              1               0               Win
# 1912              1               0               Win

# %%
# Fill in NaN values with the mean value.
mean_attendance = data['attendance'].mean()
data['attendance'].fillna((mean_attendance), inplace = True)

data.isnull().values.any()
# Out:
# False

# %%
# Game with the highest number of spectators.
max_attendance = df[df.attendance == df.attendance.max()]
max_attendance
# Out:
#      attendance             away_team  away_team_hits  away_team_runs  \
# 534     53621.0  San Francisco Giants              11               2
#
#            date   game_type            home_team  home_team_errors  \
# 534  2016-09-20  Night Game  Los Angeles Dodgers                 0
#
#      home_team_hits  home_team_runs       start_time day_of_week  temperature  \
# 534               9               0  7:10 p.m. Local     Tuesday         77.0
#
#      wind_speed  total_runs  game_hours_dec          season  home_team_win  \
# 534         6.0           2             3.6  regular season              0
#
#      home_team_loss home_team_outcome
# 534               1              Loss

# %%
def to_Celsius(F_temp: int):
    """Convert temperature from Fahrenheit to Celsius.
    f = 9/5*c + 32"""

    C_temp = np.round(5/9*(F_temp - 32), 1)
    return C_temp

# %%
# Game with the lowest temperature.
lowest_t = df[df.temperature == df.temperature.min()]
print("The lowest temperature in degrees Celsius: {}".format(
    to_Celsius(int(lowest_t.temperature))
    ))
lowest_t
# Out:
# The lowest temperature in degrees Celsius: -0.6
#       attendance         away_team  away_team_hits  away_team_runs  \
# 2409     32419.0  New York Yankees              13               8
#
#             date game_type       home_team  home_team_errors  home_team_hits  \
# 2409  2016-04-09  Day Game  Detroit Tigers                 1               7
#
#       home_team_runs       start_time day_of_week  temperature  wind_speed  \
# 2409               4  1:10 p.m. Local    Saturday         31.0        18.0
#
#       total_runs  game_hours_dec          season  home_team_win  \
# 2409          12        3.333333  regular season              0
#
#       home_team_loss home_team_outcome
# 2409               1              Loss

# %%
# Game with the highest temperature.
highest_t = df[df.temperature == df.temperature.max()]
print("The highest temperature in degrees Celsius: {}".format(
    to_Celsius(int(highest_t.temperature))
    ))
highest_t
# Out:
# The highest temperature in degrees Celsius: 38.3
#       attendance             away_team  away_team_hits  away_team_runs  \
# 2026     21753.0  San Francisco Giants               8               3
#
#             date   game_type             home_team  home_team_errors  \
# 2026  2016-05-13  Night Game  Arizona Diamondbacks                 0
#
#       home_team_hits  home_team_runs       start_time day_of_week  \
# 2026               8               1  6:40 p.m. Local      Friday
#
#       temperature  wind_speed  total_runs  game_hours_dec          season  \
# 2026        101.0         9.0           4             3.0  regular season
#
#       home_team_win  home_team_loss home_team_outcome
# 2026              0               1              Loss

# %%
# The longest game of the season.
max_hours = df[df.game_hours_dec == df.game_hours_dec.max()]
max_hours
# Out:
#       attendance          away_team  away_team_hits  away_team_runs  \
# 1445     45825.0  Cleveland Indians              15               2
#
#             date game_type          home_team  home_team_errors  \
# 1445  2016-07-01  Day Game  Toronto Blue Jays                 2
#
#       home_team_hits  home_team_runs       start_time day_of_week  \
# 1445              11               1  1:20 p.m. Local      Friday
#
#       temperature  wind_speed  total_runs  game_hours_dec          season  \
# 1445         68.0         0.0           3        6.216667  regular season
#
#       home_team_win  home_team_loss home_team_outcome
# 1445              0               1              Loss

# %%
# The shortest game of the season.
min_hours = df[df.game_hours_dec == df.game_hours_dec.min()]
min_hours
# Out:
#      attendance     away_team  away_team_hits  away_team_runs        date  \
# 423     19991.0  Chicago Cubs               4               1  2016-09-29
#
#       game_type           home_team  home_team_errors  home_team_hits  \
# 423  Night Game  Pittsburgh Pirates                 0               2
#
#      home_team_runs       start_time day_of_week  temperature  wind_speed  \
# 423               1  7:06 p.m. Local    Thursday         63.0        12.0
#
#      total_runs  game_hours_dec          season  home_team_win  \
# 423           2            1.25  regular season              0
#
#      home_team_loss home_team_outcome
# 423               0              Loss

# %%
# Games ended in a draw (by number of runs scored).
equal_runs = df.iloc[np.where(df.away_team_runs == df.home_team_runs)]
equal_runs
# Out:
#      attendance     away_team  away_team_hits  away_team_runs        date  \
# 423     19991.0  Chicago Cubs               4               1  2016-09-29
#
#       game_type           home_team  home_team_errors  home_team_hits  \
# 423  Night Game  Pittsburgh Pirates                 0               2
#
#      home_team_runs       start_time day_of_week  temperature  wind_speed  \
# 423               1  7:06 p.m. Local    Thursday         63.0        12.0
#
#      total_runs  game_hours_dec          season  home_team_win  \
# 423           2            1.25  regular season              0
#
#      home_team_loss home_team_outcome
# 423               0              Loss

# %%
# The last game of the season.
last_game = df.sort_values(by=['date', 'start_time'], ascending=False).head(1)
last_game
# Out:
#      attendance          away_team  away_team_hits  away_team_runs  \
# 395     36787.0  Toronto Blue Jays               9               2
#
#            date game_type       home_team  home_team_errors  home_team_hits  \
# 395  2016-10-02  Day Game  Boston Red Sox                 1               4
#
#      home_team_runs       start_time day_of_week  temperature  wind_speed  \
# 395               1  3:17 p.m. Local      Sunday         56.0         6.0
#
#      total_runs  game_hours_dec          season  home_team_win  \
# 395           3        3.233333  regular season              0
#
#      home_team_loss home_team_outcome
# 395               1              Loss

# %%
# Game with the lowest number of spectators.
min_attend = df[df.attendance == df.attendance.min()]
min_attend
# Out:
#       attendance       away_team  away_team_hits  away_team_runs        date  \
# 2130      8766.0  Detroit Tigers               5               0  2016-05-04
#
#        game_type          home_team  home_team_errors  home_team_hits  \
# 2130  Night Game  Cleveland Indians                 0               5
#
#       home_team_runs       start_time day_of_week  temperature  wind_speed  \
# 2130               4  6:10 p.m. Local   Wednesday         54.0        11.0
#
#       total_runs  game_hours_dec          season  home_team_win  \
# 2130           4        2.316667  regular season              1
#
#       home_team_loss home_team_outcome
# 2130               0               Win

# %%
# The most windy game.
wind_speed = df[df.wind_speed == df.wind_speed.max()]
wind_speed
# Out:
#       attendance          away_team  away_team_hits  away_team_runs  \
# 1655     41543.0  Milwaukee Brewers              11               5
# 2005     35736.0     Houston Astros               8               9
#
#             date   game_type             home_team  home_team_errors  \
# 1655  2016-06-13  Night Game  San Francisco Giants                 0
# 2005  2016-05-15    Day Game        Boston Red Sox                 3
#
#       home_team_hits  home_team_runs       start_time day_of_week  \
# 1655              14              11  7:15 p.m. Local      Monday
# 2005              14              10  1:34 p.m. Local      Sunday
#
#       temperature  wind_speed  total_runs  game_hours_dec          season  \
# 1655         58.0        25.0          16        3.633333  regular season
# 2005         58.0        25.0          19        3.666667  regular season
#
#       home_team_win  home_team_loss home_team_outcome
# 1655              1               0               Win
# 2005              1               0               Win

# %%
# Max number of total runs in the game.
total_runs = df[df.total_runs == df.total_runs.max()]
total_runs
# Out:
#       attendance         away_team  away_team_hits  away_team_runs  \
# 1788     22588.0  Seattle Mariners              16              16
#
#             date   game_type         home_team  home_team_errors  \
# 1788  2016-06-02  Night Game  San Diego Padres                 1
#
#       home_team_hits  home_team_runs       start_time day_of_week  \
# 1788              20              13  6:10 p.m. Local    Thursday
#
#       temperature  wind_speed  total_runs  game_hours_dec          season  \
# 1788         76.0        10.0          29        3.833333  regular season
#
#       home_team_win  home_team_loss home_team_outcome
# 1788              0               1              Loss

# %%
# Max number of errors made by the host team.
hteam_err = df[df.home_team_errors == df.home_team_errors.max()]
hteam_err
# Out:
#       attendance             away_team  away_team_hits  away_team_runs  \
# 1178     22581.0  Arizona Diamondbacks              11               8
#
#             date   game_type          home_team  home_team_errors  \
# 1178  2016-07-27  Night Game  Milwaukee Brewers                 5
#
#       home_team_hits  home_team_runs       start_time day_of_week  \
# 1178               5               1  7:10 p.m. Local   Wednesday
#
#       temperature  wind_speed  total_runs  game_hours_dec          season  \
# 1178         77.0         9.0           9        2.933333  regular season
#
#       home_team_win  home_team_loss home_team_outcome
# 1178              0               1              Loss

# %%
# Max number of total hits in the game.
df['total_hits'] = df[['away_team_hits', 'home_team_hits']].sum(axis=1)
total_hits = df[df.total_hits == df.total_hits.max()]
total_hits
# Out:
#       attendance      away_team  away_team_hits  away_team_runs        date  \
# 1413     36253.0  Texas Rangers              16               5  2016-07-04
#
#      game_type       home_team  home_team_errors  home_team_hits  \
# 1413  Day Game  Boston Red Sox                 2              21
#
#       home_team_runs       start_time day_of_week  temperature  wind_speed  \
# 1413              12  1:37 p.m. Local      Monday         84.0        11.0
#
#       total_runs  game_hours_dec          season  home_team_win  \
# 1413          17        3.666667  regular season              1
#
#       home_team_loss home_team_outcome  total_hits
# 1413               0               Win          37

# %%
# The number of games played by each team in a given season.
df1 = pd.DataFrame(df.away_team.value_counts(), columns=['away_team'])
df2 = pd.DataFrame(df.home_team.value_counts(), columns=['home_team'])
df3 = df1.join(df2)
df3['total_games'] = df3[['away_team', 'home_team']].sum(axis = 1)
df3.sort_index()
# Out:
#                                away_team  home_team  total_games
# Arizona Diamondbacks                  81         81          162
# Atlanta Braves                        80         81          161
# Baltimore Orioles                     81         81          162
# Boston Red Sox                        81         81          162
# Chicago Cubs                          81         81          162
# Chicago White Sox                     81         81          162
# Cincinnati Reds                       81         81          162
# Cleveland Indians                     80         81          161
# Colorado Rockies                      81         81          162
# Detroit Tigers                        81         80          161
# Houston Astros                        81         81          162
# Kansas City Royals                    81         81          162
# Los Angeles Angels of Anaheim         81         81          162
# Los Angeles Dodgers                   81         81          162
# Miami Marlins                         81         80          161
# Milwaukee Brewers                     81         81          162
# Minnesota Twins                       81         81          162
# New York Mets                         81         81          162
# New York Yankees                      81         81          162
# Oakland Athletics                     81         81          162
# Philadelphia Phillies                 81         81          162
# Pittsburgh Pirates                    81         81          162
# San Diego Padres                      81         81          162
# San Francisco Giants                  81         81          162
# Seattle Mariners                      81         81          162
# St. Louis Cardinals                   81         81          162
# Tampa Bay Rays                        81         81          162
# Texas Rangers                         81         81          162
# Toronto Blue Jays                     81         81          162
# Washington Nationals                  81         81          162

# %%
# Max number of home-team wins.
home_win = df.groupby('home_team')[['home_team_win']].sum()
home_win.sort_values(by='home_team_win', ascending=False).head()
# Out:
#                       home_team_win
# home_team
# Chicago Cubs                     57
# Cleveland Indians                53
# Los Angeles Dodgers              53
# Texas Rangers                    53
# Washington Nationals             50

# %%
# Max number of away-team wins.
away_win = data.groupby('away_team')[['home_team_loss']].sum()
away_win.sort_values(by='home_team_loss', ascending=False).head()
# Out:
#                       home_team_loss
# away_team
# Chicago Cubs                      52
# St. Louis Cardinals               48
# Washington Nationals              46
# Cleveland Indians                 46
# Boston Red Sox                    46

# %%
# Team that won the most matches in the season.
total_wins = home_win.join(away_win)
total_wins['total_wins'] = total_wins[['home_team_win', 'home_team_loss']].sum(axis = 1)
total_wins.sort_values(by='total_wins', ascending=False).head()
# Out:
#                       home_team_win  home_team_loss  total_wins
# home_team
# Chicago Cubs                     57              52         109
# Cleveland Indians                53              46          99
# Washington Nationals             50              46          96
# Texas Rangers                    53              42          95
# Los Angeles Dodgers              53              41          94

# %%
# Teams which lost the most matches in the season.
total_wins.set_index(['home_team_win'])
total_loss = total_wins.join(df3).sort_index()
total_loss['total'] = total_loss.total_games - total_loss.total_wins
total_loss[['total']].sort_values(by='total', ascending=False).head()
# Out:
#                       total
# home_team
# Minnesota Twins         103
# Tampa Bay Rays           94
# San Diego Padres         94
# Cincinnati Reds          94
# Arizona Diamondbacks     93

# %%
weekday_loss = pd.pivot_table(df,
                              index='day_of_week',
                              columns='home_team_outcome',
                              values='home_team_loss',
                              aggfunc = np.sum)
weekday_loss.drop(columns="Win", inplace=True)

total = weekday_loss.Loss.sum()

print(f"Number of losses: {total}")
weekday_loss.sort_values(by=["Loss"], ascending=False)
# Out:
# Number of losses: 1140
# home_team_outcome  Loss
# day_of_week
# Sunday              189
# Tuesday             185
# Friday              181
# Saturday            174
# Wednesday           162
# Monday              128
# Thursday            121

# %%
# Verify if the greatest number of total runs occur in cold weather
# (cold weather <= 0 degrees Celsius)
df["temperature_C"] = df.temperature.apply(to_Celsius)

df.sort_values(by="total_runs", ascending=False).head(4)
# Out:
#       attendance            away_team  away_team_hits  away_team_runs  \
# 1788     22588.0     Seattle Mariners              16              16
# 881      15690.0  Los Angeles Dodgers              21              18
# 1475     41730.0    Oakland Athletics              12              13
# 2110     41477.0     Colorado Rockies              17              17
#
#             date   game_type             home_team  home_team_errors  \
# 1788  2016-06-02  Night Game      San Diego Padres                 1
# 881   2016-08-22    Day Game       Cincinnati Reds                 0
# 1475  2016-06-28  Night Game  San Francisco Giants                 1
# 2110  2016-05-05  Night Game  San Francisco Giants                 2
#
#       home_team_hits  home_team_runs        start_time day_of_week  \
# 1788              20              13   6:10 p.m. Local    Thursday
# 881               14               9  12:36 p.m. Local      Monday
# 1475              18              11   7:16 p.m. Local     Tuesday
# 2110              16               7   7:15 p.m. Local    Thursday
#
#       temperature  wind_speed  total_runs  game_hours_dec          season  \
# 1788         76.0        10.0          29        3.833333  regular season
# 881          76.0         3.0          27        4.033333  regular season
# 1475         59.0        16.0          24        3.883333  regular season
# 2110         62.0        10.0          24        3.416667  regular season
#
#       home_team_win  home_team_loss home_team_outcome  total_hits  \
# 1788              0               1              Loss          36
# 881               0               1              Loss          35
# 1475              0               1              Loss          30
# 2110              0               1              Loss          33
#
#       temperature_C
# 1788           24.4
# 881            24.4
# 1475           15.0
# 2110           16.7

# %%
df.iloc[np.where(df.temperature_C <= 0)]
# Out:
#       attendance          away_team  away_team_hits  away_team_runs  \
# 2409     32419.0   New York Yankees              13               8
# 2412     20192.0  Cleveland Indians               7               3
#
#             date game_type          home_team  home_team_errors  \
# 2409  2016-04-09  Day Game     Detroit Tigers                 1
# 2412  2016-04-09  Day Game  Chicago White Sox                 1
#
#       home_team_hits  home_team_runs       start_time day_of_week  \
# 2409               7               4  1:10 p.m. Local    Saturday
# 2412              10               7  1:10 p.m. Local    Saturday
#
#       temperature  wind_speed  total_runs  game_hours_dec          season  \
# 2409         31.0        18.0          12        3.333333  regular season
# 2412         32.0        13.0          10        2.716667  regular season
#
#       home_team_win  home_team_loss home_team_outcome  total_hits  \
# 2409              0               1              Loss          20
# 2412              1               0               Win          17
#
#       temperature_C
# 2409           -0.6
# 2412            0.0
